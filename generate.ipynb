# %%
import numpy as np
import pandas as pd
from PIL import Image, ImageDraw, ImageChops
import random
import colorsys
import math
import matplotlib.pyplot as plt

# %%
import bright_ellipses
import bright_lines

bright_lines.generate_art()
bright_ellipses.generate_art2()
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F7CC2C309D0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F7CC323CAD0>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2222f6ad-f2a8-4783-aa35-acdebe99246c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
